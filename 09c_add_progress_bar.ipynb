# %% [markdown]
# # Adding progress bars to Learner

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
#export
from google.colab import drive
drive.mount("/content/gdrive")
# %cd gdrive/MyDrive/Ml/nbs/dl2/
from exp.nb_09b import *
import time
from fastprogress.fastprogress import master_bar, progress_bar
from fastprogress.fastprogress import format_time
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Ml/nbs/dl2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-243fa363739e> in <module>()
#       3 drive.mount("/content/gdrive")
#       4 get_ipython().magic('cd gdrive/MyDrive/Ml/nbs/dl2/')
# ----> 5 from exp.nb_09b import *
#       6 import time
#       7 from fastprogress.fastprogress import master_bar, progress_bar
#
# /content/gdrive/MyDrive/Ml/nbs/dl2/exp/nb_09b.py in <module>()
#       5 # file to edit: dev_nb/09b_learner.ipynb
#       6
# ----> 7 from exp.nb_09 import *
#       8
#       9 def param_getter(m): return m.parameters()
#
# /content/gdrive/MyDrive/Ml/nbs/dl2/exp/nb_09.py in <module>()
#       5 # file to edit: dev_nb/09_optimizers.ipynb
#       6
# ----> 7 from exp.nb_08 import *
#       8
#       9 def sgd_step(p, lr, **kwargs):
#
# /content/gdrive/MyDrive/Ml/nbs/dl2/exp/nb_08.py in <module>()
#     204 _m = tensor([0.47, 0.48, 0.45])
#     205 _s = tensor([0.29, 0.28, 0.30])
# --> 206 norm_imagenette = partial(normalize_chan, mean=_m.cuda(), std=_s.cuda())
#     207
#     208 import math
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     168         # This function throws if there's a driver initialization error, no GPUs
#     169         # are found or any other error occurs
# --> 170         torch._C._cuda_init()
#     171         # Some of the queued calls may reentrantly call _lazy_init();
#     172         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %% [markdown]
# One thing has been missing all this time, and as fun as it is to stare at a blank screen waiting for the results, it's nicer to have some tool to track progress.

# %% [markdown]
# ## Imagenette data

# %% [markdown]
# [Jump_to lesson 11 video](https://course19.fast.ai/videos/?lesson=11&t=6743)

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)

# %%
tfms = [make_rgb, ResizeFixed(128), to_byte_tensor, to_float_tensor]
bs = 64

il = ImageList.from_files(path, tfms=tfms)
sd = SplitData.split_by_func(il, partial(grandparent_splitter, valid_name='val'))
ll = label_by_func(sd, parent_labeler, proc_y=CategoryProcessor())
data = ll.to_databunch(bs, c_in=3, c_out=10, num_workers=4)

# %%
nfs = [32]*4

# %% [markdown]
# We rewrite the `AvgStatsCallback` to add a line with the names of the things measured and keep track of the time per epoch.

# %%
# export 
class AvgStatsCallback(Callback):
    def __init__(self, metrics):
        self.train_stats,self.valid_stats = AvgStats(metrics,True),AvgStats(metrics,False)
    
    def begin_fit(self):
        met_names = ['loss'] + [m.__name__ for m in self.train_stats.metrics]
        names = ['epoch'] + [f'train_{n}' for n in met_names] + [
            f'valid_{n}' for n in met_names] + ['time']
        self.logger(names) #print representation
    
    def begin_epoch(self):
        self.train_stats.reset()
        self.valid_stats.reset()
        self.start_time = time.time()
        
    def after_loss(self):
        stats = self.train_stats if self.in_train else self.valid_stats
        with torch.no_grad(): stats.accumulate(self.run)
    
    def after_epoch(self):
        stats = [str(self.epoch)] 
        for o in [self.train_stats, self.valid_stats]:
            stats += [f'{v:.6f}' for v in o.avg_stats] 
        stats += [format_time(time.time() - self.start_time)]
        self.logger(stats)

# %% [markdown]
# Then we add the progress bars... with a Callback of course! `master_bar` handles the count over the epochs while its child `progress_bar` is looping over all the batches. We just create one at the beginning or each epoch/validation phase, and update it at the end of each batch. By changing the logger of the `Learner` to the `write` function of the master bar, everything is automatically written there.
#
# Note: this requires fastprogress v0.1.21 or later.

# %%
# export 
class ProgressCallback(Callback):
    _order=-1
    def begin_fit(self):
        self.mbar = master_bar(range(self.epochs))
        self.mbar.on_iter_begin() #start
        self.run.logger = partial(self.mbar.write, table=True) # 함수에서 table true로 바꾸기
        
    def after_fit(self): self.mbar.on_iter_end() # finish
    def after_batch(self): self.pb.update(self.iter) # update every batch
    def begin_epoch   (self): self.set_pb()
    def begin_validate(self): self.set_pb()
        
    def set_pb(self):
        self.pb = progress_bar(self.dl, parent=self.mbar) # masterbar에 subbar 등록
        self.mbar.update(self.epoch) # update

# %% [markdown]
# By making the progress bar a callback, you can easily choose if you want to have them shown or not.

# %%
cbfs = [partial(AvgStatsCallback,accuracy),
        CudaCallback,
        ProgressCallback,
        partial(BatchTransformXCallback, norm_imagenette)]

# %%
learn = get_learner(nfs, data, 0.4, conv_layer, cb_funcs=cbfs)

# %%
learn.fit(2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.839106</td>
#       <td>0.356849</td>
#       <td>1.940670</td>
#       <td>0.364076</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.500339</td>
#       <td>0.490865</td>
#       <td>1.692970</td>
#       <td>0.423439</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Export

# %%
# !./notebook2script.py 09c_add_progress_bar.ipynb
# Out:
# Converted 09c_add_progress_bar.ipynb to exp/nb_09c.py
