# %%
#export
TEST = 'test'

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install fire
# Out:
# Collecting fire
#   Downloading https://files.pythonhosted.org/packages/11/07/a119a1aa04d37bc819940d95ed7e135a7dcca1c098123a3764a6dcace9e7/fire-0.4.0.tar.gz (87kB)
#      |████████████████████████████████| 92kB 5.2MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire) (1.1.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=0962bd7bd9cdc018acfe1f5ddda158bdfd3a5e54ce73c1b2f5fa8c6a9cb89b1e
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.4.0

# %% [markdown]
# ## Export

# %%
# %cd gdrive/MyDrive/Ml/nbs/dl2
# !python notebook2script.py 00_exports.ipynb
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Ml/nbs/dl2'
# /content/gdrive/MyDrive/Ml/nbs/dl2
# Converted 00_exports.ipynb to exp/nb_00.py

# %% [markdown]
# ### How it works:

# %%
import json
d = json.load(open('00_exports.ipynb','r'))['cells']

# %%
d
# Out:
# [{'cell_type': 'code',
#   'execution_count': 2,
#   'metadata': {'executionInfo': {'elapsed': 14739,
#     'status': 'ok',
#     'timestamp': 1614854590721,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': 'Amq_ifwx1KWf'},
#   'outputs': [],
#   'source': ['#export\n', "TEST = 'test'"]},
#  {'cell_type': 'code',
#   'execution_count': 1,
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'executionInfo': {'elapsed': 15292,
#     'status': 'ok',
#     'timestamp': 1614854590720,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': 'RSDAEUZX1T7K',
#    'outputId': '9737dc01-4043-4b64-d78c-4c51bafbfc93'},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['Mounted at /content/gdrive\n']}],
#   'source': ['from google.colab import drive\n',
#    'drive.mount("/content/gdrive")']},
#  {'cell_type': 'code',
#   'execution_count': 7,
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'executionInfo': {'elapsed': 5167,
#     'status': 'ok',
#     'timestamp': 1614854664883,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': 'Qk8KRcFp1ory',
#    'outputId': 'a55e6588-3803-4125-80d8-6d52b47b3720'},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['Collecting fire\n',
#      '\x1b[?25l  Downloading https://files.pythonhosted.org/packages/11/07/a119a1aa04d37bc819940d95ed7e135a7dcca1c098123a3764a6dcace9e7/fire-0.4.0.tar.gz (87kB)\n',
#      '\r\x1b[K     |███▊                            | 10kB 17.9MB/s eta 0:00:01\r\x1b[K     |███████▌                        | 20kB 18.0MB/s eta 0:00:01\r\x1b[K     |███████████▏                    | 30kB 10.4MB/s eta 0:00:01\r\x1b[K     |███████████████                 | 40kB 8.8MB/s eta 0:00:01\r\x1b[K     |██████████████████▊             | 51kB 7.1MB/s eta 0:00:01\r\x1b[K     |██████████████████████▍         | 61kB 7.3MB/s eta 0:00:01\r\x1b[K     |██████████████████████████▏     | 71kB 7.7MB/s eta 0:00:01\r\x1b[K     |██████████████████████████████  | 81kB 8.1MB/s eta 0:00:01\r\x1b[K     |████████████████████████████████| 92kB 5.2MB/s \n',
#      '\x1b[?25hRequirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire) (1.15.0)\n',
#      'Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire) (1.1.0)\n',
#      'Building wheels for collected packages: fire\n',
#      '  Building wheel for fire (setup.py) ... \x1b[?25l\x1b[?25hdone\n',
#      '  Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=0962bd7bd9cdc018acfe1f5ddda158bdfd3a5e54ce73c1b2f5fa8c6a9cb89b1e\n',
#      '  Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed\n',
#      'Successfully built fire\n',
#      'Installing collected packages: fire\n',
#      'Successfully installed fire-0.4.0\n']}],
#   'source': ['!pip install fire']},
#  {'cell_type': 'markdown',
#   'metadata': {'id': '9SrieNVM1KWi'},
#   'source': ['## Export']},
#  {'cell_type': 'code',
#   'execution_count': 6,
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'executionInfo': {'elapsed': 830,
#     'status': 'ok',
#     'timestamp': 1614854651319,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': '_r61nrHg1KWi',
#    'outputId': '1929dbf1-194f-40db-8cf6-2789c609b9bb'},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['/content/gdrive/MyDrive/Ml/nbs/dl2\n',
#      'Traceback (most recent call last):\n',
#      '  File "notebook2script.py", line 3, in <module>\n',
#      '    import json,fire,re\n',
#      "ModuleNotFoundError: No module named 'fire'\n"]}],
#   'source': ['%cd gdrive/MyDrive/Ml/nbs/dl2\n',
#    '!python notebook2script.py 00_exports.ipynb']},
#  {'cell_type': 'code',
#   'execution_count': 9,
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'executionInfo': {'elapsed': 588,
#     'status': 'error',
#     'timestamp': 1614854679678,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': 'KcnQ6oRU1gdk',
#    'outputId': '181d4f05-6f76-4ad1-99a5-9c4fde7b4b35'},
#   'outputs': [{'name': 'stderr',
#     'output_type': 'stream',
#     'text': ['UsageError: Line magic function `%vim` not found.\n']}],
#   'source': ['']},
#  {'cell_type': 'markdown',
#   'metadata': {'id': 'KTEiPrUq1KWi'},
#   'source': ['### How it works:']},
#  {'cell_type': 'code',
#   'execution_count': 4,
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 187},
#    'executionInfo': {'elapsed': 647,
#     'status': 'error',
#     'timestamp': 1614854593837,
#     'user': {'displayName': 'Hyukhun Koh',
#      'photoUrl': 'https://lh3.googleusercontent.com/a-/AOh14GjFmQFILEivwghVAUWhEtg_t_piycJmb4VOpPQS=s64',
#      'userId': '04457846064668801006'},
#     'user_tz': -540},
#    'id': '9KDHS25g1KWj',
#    'outputId': 'c256d8b1-fa06-4975-8d03-729a8a058441'},
#   'outputs': [{'ename': 'FileNotFoundError',
#     'evalue': 'ignored',
#     'output_type': 'error',
#     'traceback': ['\x1b---------------------------------------------------------------------------\x1b',
#      '\x1bFileNotFoundError\x1b                         Traceback (most recent call last)',
#      "\x1b<ipython-input-4-4df20edcad6c>\x1b in \x1b<module>\x1b()\x1b\n\x1b      1\x1b \x1bimport\x1b \x1bjson\x1b\x1b\x1b\x1b\x1b\x1b\n\x1b----> 2\x1b \x1bd\x1b \x1b=\x1b \x1bjson\x1b\x1b.\x1b\x1bload\x1b\x1b(\x1b\x1bopen\x1b\x1b(\x1b\x1b'00_exports.ipynb'\x1b\x1b,\x1b\x1b'r'\x1b\x1b)\x1b\x1b)\x1b\x1b[\x1b\x1b'cells'\x1b\x1b[0;34m]\x1b\x1b\x1b\x1b\x1b\x1b\n\x1b",
#      "\x1bFileNotFoundError\x1b: [Errno 2] No such file or directory: '00_exports.ipynb'"]}],
#   'source': ['import json\n',
#    "d = json.load(open('00_exports.ipynb','r'))['cells']"]},
#  {'cell_type': 'code',
#   'execution_count': None,
#   'metadata': {'id': 'pd1xY5YM1KWj'},
#   'outputs': [],
#   'source': ['d[0]']},
#  {'cell_type': 'code',
#   'execution_count': None,
#   'metadata': {'id': 'RQcBc8j91KWj'},
#   'outputs': [],
#   'source': ['']}]

# %%
from fastai.vision import *

# already in fastaudio, can download with fastai's `untar_data`
path = untar_data(URLs.ESC50)
wavs = (path/"audio").ls()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3f00cf502502> in <module>()
#       2
#       3 # already in fastaudio, can download with fastai's `untar_data`
# ----> 4 path = untar_data(URLs.ESC50)
#       5 wavs = (path/"audio").ls()
#
# AttributeError: type object 'URLs' has no attribute 'ESC50'

# %%
wavs = (path/"audio").ls()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-78c524b9e617> in <module>()
# ----> 1 wavs = (path/"audio").ls()
#
# NameError: name 'path' is not defined
